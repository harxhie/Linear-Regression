# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Harshita Raj Singh\Desktop\datasets\canada_per_capita_income.csv")
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# 26  1996             16699.826680
# 27  1997             17310.757750
# 28  1998             16622.671870
# 29  1999             17581.024140
# 30  2000             18987.382410
# 31  2001             18601.397240
# 32  2002             19232.175560
# 33  2003             22739.426280
# 34  2004             25719.147150
# 35  2005             29198.055690
# 36  2006             32738.262900
# 37  2007             36144.481220
# 38  2008             37446.486090
# 39  2009             32755.176820
# 40  2010             38420.522890
# 41  2011             42334.711210
# 42  2012             42665.255970
# 43  2013             42676.468370
# 44  2014             41039.893600
# 45  2015             35175.188980
# 46  2016             34229.193630

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df['year'], df['per capita income (US$)'])
plt.show()

# %%
X = df[['year']]
Y = df['per capita income (US$)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     year
# 4   1974
# 40  2010
# 12  1982
# 44  2014
# 23  1993
# 43  2013
# 31  2001
# 32  2002
# 3   1973
# 10  1980

# %%
clf.predict(X_test)
# Out:
# array([ 3401.76400502, 32534.08646919,  9875.61344151, 35771.01118743,
#        18777.15641667, 34961.78000787, 25251.00585315, 26060.23703271,
#         2592.53282546,  8257.15108238])

# %%
Y_test
# Out:
# 4      5576.514583
# 40    38420.522890
# 12     9619.438377
# 44    41039.893600
# 23    15875.586730
# 43    42676.468370
# 31    18601.397240
# 32    19232.175560
# 3      4804.463248
# 10     8355.968120
# Name: per capita income (US$), dtype: float64

# %%
clf.predict(Y_test.values.reshape(-1, 1))
# Out:
# C:\Users\Harshita Raj Singh\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([ 2918668.88938918, 29497064.47315005,  6190328.88008008,
#        31616740.92250897, 11252999.1912823 , 32941108.25407465,
#        13458810.04554738, 13969255.52948202,  2293900.87688605,
#         5167889.35366865])

# %%
clf.score(X_test, Y_test)
# Out:
# 0.8843432049803693
